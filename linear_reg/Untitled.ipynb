# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !!ls
# Out:
# ['Untitled.ipynb', '__pycache__', 'data', 'utils.py']

# %%
import matplotlib.pyplot as plt
from utils import *

# %%
datapath = "data/data.csv"

# %%
X, Y = load_data(datapath)

# %%
plt.scatter(X,Y)
plt.title("Car prices / km")
plt.xlabel("km")
plt.ylabel("price")
plt.show()

# %%
X = normalize(X)
theta = train(X, Y)
print(theta)
# Out:
# [733.88567699360328, -207.94322270250117]

# %%
plt.scatter(X,Y)
plt.title("Car prices / km")
plt.xlabel("km")
plt.ylabel("price")
plt.plot([-3, 3], [predict(-3, theta), predict(3, theta)], linestyle='-')
plt.show()
